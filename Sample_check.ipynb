# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()
df = spark.read.csv("/Volumes/workspace/default/practisevolume1/name  salary.csv",header=True, inferSchema=True )
df.show()
df.printSchema()
